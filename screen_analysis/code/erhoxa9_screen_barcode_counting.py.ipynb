# %%
import pandas as pd
import numpy as np
from collections import Counter, defaultdict
import glob
import seaborn as sns
import gzip
import matplotlib.pyplot as plt
from adjustText import adjust_text

# %%
allowed_barcodes = pd.read_excel("../data/220922_BD354_barcodes.xlsx").iloc[:42,]
allowed_barcodes["Name"] = [x.replace("BD354_", "") for x in allowed_barcodes["Name"]]
allowed_barcodes.head()
# Out:
#    Sample num    Tx Antibody Fraction  Replicate                  Name  \
# 0         1.0  DMSO    CD11b      low        1.0   DMSO_CD11b_low_rep1
# 1         2.0  DMSO    CD11b     high        1.0  DMSO_CD11b_high_rep1
# 2         3.0  DMSO    CD11b      low        2.0   DMSO_CD11b_low_rep2
# 3         4.0  DMSO    CD11b     high        2.0  DMSO_CD11b_high_rep2
# 4         5.0  DMSO      GFP      low        1.0     DMSO_GFP_low_rep1
#
#   Cell number Nanodrop 1:10        ul    nM   P5   P7  hash  Unnamed: 13  \
# 0         NaN          21.5  4.651163   NaN  1.0  1.0  11.0          NaN
# 1         NaN          18.6  5.376344  25.2  2.0  2.0  22.0          NaN
# 2         NaN          12.5         8   NaN  3.0  3.0  33.0          NaN
# 3         NaN            16      6.25   NaN  4.0  4.0  44.0          NaN
# 4         NaN          15.3  6.535948   NaN  5.0  5.0  55.0          NaN
#
#   index 1 (P7) index 2 (P5)  Unnamed: 16                     Unnamed: 17  \
# 0     ATTACTCG     AGGCTATA          NaN                             NaN
# 1     TCCGGAGA     GCCTCTAT          NaN  Conversion from nanodrop to nM
# 2     CGCTCATT     AGGATAGG          NaN                        nanodrop
# 3     GAGATTCC     TCAGAGCC          NaN                            18.6
# 4     ATTCAGAA     CTTCGCCT          NaN                            16.4
#
#   Unnamed: 18
# 0         NaN
# 1         NaN
# 2          nM
# 3        25.2
# 4        21.7

# %%
# weissman sgRNAs
library = pd.read_csv("../data/TableS4_mCRISPRiv2_library.csv")
library = library[library["Sublibrary half"] == "Top5"]

weissman_guides = [x.upper() for x in list(library["protospacer sequence"])]
library.head()
# Out:
#                                sgID           gene transcript  \
# 0  0610007P14Rik_+_85824465.23-P1P2  0610007P14Rik       P1P2
# 1  0610007P14Rik_+_85824469.23-P1P2  0610007P14Rik       P1P2
# 2  0610007P14Rik_+_85824478.23-P1P2  0610007P14Rik       P1P2
# 3  0610007P14Rik_+_85824456.23-P1P2  0610007P14Rik       P1P2
# 4  0610007P14Rik_+_85824523.23-P1P2  0610007P14Rik       P1P2
#
#    protospacer sequence  selection rank  predicted score  empirical score  \
# 0  GTAGTACTGGATCGTCAGGT             1.0         0.898157              NaN
# 1  GGCAGTAGTACTGGATCGTC             2.0         0.862836              NaN
# 2  GGATACTGCTGCAGTAGTAC             3.0         0.760573              NaN
# 3  GATCGTCAGGTAGGAGAATT             4.0         0.747215              NaN
# 4  GTGGGACCGGAGCTGGCCTA             5.0         0.740656              NaN
#
#    off-target stringency Sublibrary Sublibrary half
# 0                      0         m3            Top5
# 1                      0         m3            Top5
# 2                      0         m3            Top5
# 3                      0         m3            Top5
# 4                      0         m3            Top5

# %%
def get_lines(fn, counter, start_at_zero=False):
    i = 0
    with gzip.open(fn,'r') as fin:
        for line in fin:
            i += 1
            if ((i + 2) % 4 == 0): 
                # change the first letter to G because it's often read wrong
                # also read the first 20
                if not start_at_zero: seq = 'G' + line.rstrip()[1:20].decode() 
                else: seq = 'G' + line.rstrip()[:19].decode() 
                
                if seq not in counter: counter[seq] = 1
                else: counter[seq] += 1
        
    return(counter)

# get dictionary of reads for all files
def get_read_dict(fn1, fn2, fn3, fn4, fn5):
    print(fn1)
    counter = defaultdict(lambda: 0)
    
    counter = get_lines(fn1, counter)
    counter = get_lines(fn2, counter)
    counter = get_lines(fn3, counter)
    counter = get_lines(fn4, counter)
    counter = get_lines(fn5, counter, start_at_zero=True)  # these were from the third run where the first base is not G 

    
    return(dict(counter))

# %%
# fix the counter for fn5, which didn't get added because I forgot to set start_at_zero to True

for j in range(42):
    # these samples were numbered 1 to 42
    fn5 = glob.glob("../fastq_guess3/*_" + str(j+1) + ".fastq.gz")[0]
    print(fn5)
    print(j)

    sample_to_dicts[j] = get_lines(fn5, sample_to_dicts[j], start_at_zero=True)
# Out:
# ../fastq_guess3/ATTACTCG_AGGCTATA_1.fastq.gz
# 0
# ../fastq_guess3/TCCGGAGA_GCCTCTAT_2.fastq.gz
# 1
# ../fastq_guess3/CGCTCATT_AGGATAGG_3.fastq.gz
# 2
# ../fastq_guess3/GAGATTCC_TCAGAGCC_4.fastq.gz
# 3
# ../fastq_guess3/ATTCAGAA_CTTCGCCT_5.fastq.gz
# 4
# ../fastq_guess3/GAATTCGT_TAAGATTA_6.fastq.gz
# 5
# ../fastq_guess3/ATTACTCG_ACGTCCTG_7.fastq.gz
# 6
# ../fastq_guess3/TCCGGAGA_AGGCTATA_8.fastq.gz
# 7
# ../fastq_guess3/CGCTCATT_GCCTCTAT_9.fastq.gz
# 8
# ../fastq_guess3/GAGATTCC_AGGATAGG_10.fastq.gz
# 9
# ../fastq_guess3/ATTCAGAA_TCAGAGCC_11.fastq.gz
# 10
# ../fastq_guess3/GAATTCGT_CTTCGCCT_12.fastq.gz
# 11
# ../fastq_guess3/ATTACTCG_TAAGATTA_13.fastq.gz
# 12
# ../fastq_guess3/TCCGGAGA_ACGTCCTG_14.fastq.gz
# 13
# ../fastq_guess3/CGCTCATT_AGGCTATA_15.fastq.gz
# 14
# ../fastq_guess3/GAGATTCC_GCCTCTAT_16.fastq.gz
# 15
# ../fastq_guess3/ATTCAGAA_AGGATAGG_17.fastq.gz
# 16
# ../fastq_guess3/GAATTCGT_TCAGAGCC_18.fastq.gz
# 17
# ../fastq_guess3/ATTACTCG_CTTCGCCT_19.fastq.gz
# 18
# ../fastq_guess3/TCCGGAGA_TAAGATTA_20.fastq.gz
# 19
# ../fastq_guess3/CGCTCATT_ACGTCCTG_21.fastq.gz
# 20
# ../fastq_guess3/GAGATTCC_AGGCTATA_22.fastq.gz
# 21
# ../fastq_guess3/ATTCAGAA_GCCTCTAT_23.fastq.gz
# 22
# ../fastq_guess3/GAATTCGT_AGGATAGG_24.fastq.gz
# 23
# ../fastq_guess3/ATTACTCG_TCAGAGCC_25.fastq.gz
# 24
# ../fastq_guess3/TCCGGAGA_CTTCGCCT_26.fastq.gz
# 25
# ../fastq_guess3/CGCTCATT_TAAGATTA_27.fastq.gz
# 26
# ../fastq_guess3/GAGATTCC_ACGTCCTG_28.fastq.gz
# 27
# ../fastq_guess3/ATTCAGAA_AGGCTATA_29.fastq.gz
# 28
# ../fastq_guess3/GAATTCGT_GCCTCTAT_30.fastq.gz
# 29
# ../fastq_guess3/ATTACTCG_AGGATAGG_31.fastq.gz
# 30
# ../fastq_guess3/TCCGGAGA_TCAGAGCC_32.fastq.gz
# 31
# ../fastq_guess3/CGCTCATT_CTTCGCCT_33.fastq.gz
# 32
# ../fastq_guess3/GAGATTCC_TAAGATTA_34.fastq.gz
# 33
# ../fastq_guess3/ATTCAGAA_ACGTCCTG_35.fastq.gz
# 34
# ../fastq_guess3/GAATTCGT_AGGCTATA_36.fastq.gz
# 35
# ../fastq_guess3/ATTACTCG_GCCTCTAT_37.fastq.gz
# 36
# ../fastq_guess3/TCCGGAGA_AGGATAGG_38.fastq.gz
# 37
# ../fastq_guess3/CGCTCATT_TCAGAGCC_39.fastq.gz
# 38
# ../fastq_guess3/GAGATTCC_CTTCGCCT_40.fastq.gz
# 39
# ../fastq_guess3/ATTCAGAA_TAAGATTA_41.fastq.gz
# 40
# ../fastq_guess3/GAATTCGT_ACGTCCTG_42.fastq.gz
# 41

# %%
sample_to_dicts = []

for i in range(42):
    # these samples were numbered 1 to 42
    fn1 = glob.glob("../fastq_guess/*_" + str(i+1) + ".fastq.gz")[0]
    fn3 = glob.glob("../fastq_guess2/*_" + str(i+1) + ".fastq.gz")[0]
    fn5 = glob.glob("../fastq_guess3/*_" + str(i+1) + ".fastq.gz")[0]

    # these samples were numbered starting from 2 to 43
    fn2 = "../fastq_perfect/220927Van_D22-2430" + str(i+2).zfill(2) + "_NA_sequence.fastq.gz"
    fn4 = "../fastq_perfect2/220927Van_D22-2430" + str(i+2).zfill(2) + "_NA_sequence.fastq.gz"
    sample_to_dicts.append(get_read_dict(fn1, fn2, fn3, fn4, fn5))
# Out:
# ../fastq_guess/ATTACTCG_AGGCTATA_1.fastq.gz
# ../fastq_guess/TCCGGAGA_GCCTCTAT_2.fastq.gz
# ../fastq_guess/CGCTCATT_AGGATAGG_3.fastq.gz
# ../fastq_guess/GAGATTCC_TCAGAGCC_4.fastq.gz
# ../fastq_guess/ATTCAGAA_CTTCGCCT_5.fastq.gz
# ../fastq_guess/GAATTCGT_TAAGATTA_6.fastq.gz
# ../fastq_guess/ATTACTCG_ACGTCCTG_7.fastq.gz
# ../fastq_guess/TCCGGAGA_AGGCTATA_8.fastq.gz
# ../fastq_guess/CGCTCATT_GCCTCTAT_9.fastq.gz
# ../fastq_guess/GAGATTCC_AGGATAGG_10.fastq.gz
# ../fastq_guess/ATTCAGAA_TCAGAGCC_11.fastq.gz
# ../fastq_guess/GAATTCGT_CTTCGCCT_12.fastq.gz
# ../fastq_guess/ATTACTCG_TAAGATTA_13.fastq.gz
# ../fastq_guess/TCCGGAGA_ACGTCCTG_14.fastq.gz
# ../fastq_guess/CGCTCATT_AGGCTATA_15.fastq.gz
# ../fastq_guess/GAGATTCC_GCCTCTAT_16.fastq.gz
# ../fastq_guess/ATTCAGAA_AGGATAGG_17.fastq.gz
# ../fastq_guess/GAATTCGT_TCAGAGCC_18.fastq.gz
# ../fastq_guess/ATTACTCG_CTTCGCCT_19.fastq.gz
# ../fastq_guess/TCCGGAGA_TAAGATTA_20.fastq.gz
# ../fastq_guess/CGCTCATT_ACGTCCTG_21.fastq.gz
# ../fastq_guess/GAGATTCC_AGGCTATA_22.fastq.gz
# ../fastq_guess/ATTCAGAA_GCCTCTAT_23.fastq.gz
# ../fastq_guess/GAATTCGT_AGGATAGG_24.fastq.gz
# ../fastq_guess/ATTACTCG_TCAGAGCC_25.fastq.gz
# ../fastq_guess/TCCGGAGA_CTTCGCCT_26.fastq.gz
# ../fastq_guess/CGCTCATT_TAAGATTA_27.fastq.gz
# ../fastq_guess/GAGATTCC_ACGTCCTG_28.fastq.gz
# ../fastq_guess/ATTCAGAA_AGGCTATA_29.fastq.gz
# ../fastq_guess/GAATTCGT_GCCTCTAT_30.fastq.gz
# ../fastq_guess/ATTACTCG_AGGATAGG_31.fastq.gz
# ../fastq_guess/TCCGGAGA_TCAGAGCC_32.fastq.gz
# ../fastq_guess/CGCTCATT_CTTCGCCT_33.fastq.gz
# ../fastq_guess/GAGATTCC_TAAGATTA_34.fastq.gz
# ../fastq_guess/ATTCAGAA_ACGTCCTG_35.fastq.gz
# ../fastq_guess/GAATTCGT_AGGCTATA_36.fastq.gz
# ../fastq_guess/ATTACTCG_GCCTCTAT_37.fastq.gz
# ../fastq_guess/TCCGGAGA_AGGATAGG_38.fastq.gz
# ../fastq_guess/CGCTCATT_TCAGAGCC_39.fastq.gz
# ../fastq_guess/GAGATTCC_CTTCGCCT_40.fastq.gz
# ../fastq_guess/ATTCAGAA_TAAGATTA_41.fastq.gz
# ../fastq_guess/GAATTCGT_ACGTCCTG_42.fastq.gz

# %%
import pickle
pickle.dump(sample_to_dicts, open("221029_bd354_counts.pkl", "wb" ) )

# %%
# a dict of count vectors
sample_to_counts = {}
for i in range(42):
    sample_to_counts[i] = [sample_to_dicts[i].get(k, 0) for k in weissman_guides]

# %%
counts = pd.DataFrame.from_dict(sample_to_counts)
counts.index = library["sgID"]
counts.columns = allowed_barcodes["Name"]

counts.to_csv("221029_bd354_counts_by_sgrna.csv")
counts.head()
# Out:
# Name                              DMSO_CD11b_low_rep1  DMSO_CD11b_high_rep1  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                  123                   120
# 0610007P14Rik_+_85824469.23-P1P2                  144                   152
# 0610007P14Rik_+_85824478.23-P1P2                  250                   302
# 0610007P14Rik_+_85824456.23-P1P2                   58                    98
# 0610007P14Rik_+_85824523.23-P1P2                   65                   122
#
# Name                              DMSO_CD11b_low_rep2  DMSO_CD11b_high_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                   63                   101
# 0610007P14Rik_+_85824469.23-P1P2                  105                   132
# 0610007P14Rik_+_85824478.23-P1P2                  268                   259
# 0610007P14Rik_+_85824456.23-P1P2                  107                   140
# 0610007P14Rik_+_85824523.23-P1P2                   65                    93
#
# Name                              DMSO_GFP_low_rep1  DMSO_GFP_high_rep1  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                103                 126
# 0610007P14Rik_+_85824469.23-P1P2                134                 184
# 0610007P14Rik_+_85824478.23-P1P2                365                 523
# 0610007P14Rik_+_85824456.23-P1P2                113                 108
# 0610007P14Rik_+_85824523.23-P1P2                132                 172
#
# Name                              DMSO_GFP_low_rep2  DMSO_GFP_high_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                208                 118
# 0610007P14Rik_+_85824469.23-P1P2                213                 148
# 0610007P14Rik_+_85824478.23-P1P2                536                 435
# 0610007P14Rik_+_85824456.23-P1P2                171                 148
# 0610007P14Rik_+_85824523.23-P1P2                150                 101
#
# Name                              HU_CD11b_low_rep1  HU_CD11b_high_rep1  ...  \
# sgID                                                                     ...
# 0610007P14Rik_+_85824465.23-P1P2                118                 140  ...
# 0610007P14Rik_+_85824469.23-P1P2                126                 132  ...
# 0610007P14Rik_+_85824478.23-P1P2                348                 259  ...
# 0610007P14Rik_+_85824456.23-P1P2                109                 122  ...
# 0610007P14Rik_+_85824523.23-P1P2                 69                  94  ...
#
# Name                              Day0_all_all_rep1  Day0_all_all_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                307                115
# 0610007P14Rik_+_85824469.23-P1P2                214                133
# 0610007P14Rik_+_85824478.23-P1P2                672                326
# 0610007P14Rik_+_85824456.23-P1P2                192                 87
# 0610007P14Rik_+_85824523.23-P1P2                234                119
#
# Name                              DMSO_all_all_rep1  DMSO_all_all_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                167                136
# 0610007P14Rik_+_85824469.23-P1P2                172                206
# 0610007P14Rik_+_85824478.23-P1P2                430                400
# 0610007P14Rik_+_85824456.23-P1P2                102                101
# 0610007P14Rik_+_85824523.23-P1P2                132                139
#
# Name                              HU_all_all_rep1  HU_all_all_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2              122              125
# 0610007P14Rik_+_85824469.23-P1P2              147              123
# 0610007P14Rik_+_85824478.23-P1P2              417              391
# 0610007P14Rik_+_85824456.23-P1P2              156              135
# 0610007P14Rik_+_85824523.23-P1P2              109              113
#
# Name                              APH_all_all_rep1  APH_all_all_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                61               127
# 0610007P14Rik_+_85824469.23-P1P2               118               184
# 0610007P14Rik_+_85824478.23-P1P2               173               422
# 0610007P14Rik_+_85824456.23-P1P2                80               104
# 0610007P14Rik_+_85824523.23-P1P2                91               106
#
# Name                              E2wd_all_all_rep1  E2wd_all_all_rep2
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                334                100
# 0610007P14Rik_+_85824469.23-P1P2                261                137
# 0610007P14Rik_+_85824478.23-P1P2                694                247
# 0610007P14Rik_+_85824456.23-P1P2                243                 74
# 0610007P14Rik_+_85824523.23-P1P2                187                 82
#
# [5 rows x 42 columns]

# %% [markdown]
# ## MAGECK

# %%
counts_mageck = pd.read_csv("221029_bd354_counts_by_sgrna.csv", index_col=0)
counts_mageck.head()
# Out:
#                                   DMSO_CD11b_low_rep1  DMSO_CD11b_high_rep1  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                  123                   120
# 0610007P14Rik_+_85824469.23-P1P2                  144                   152
# 0610007P14Rik_+_85824478.23-P1P2                  250                   302
# 0610007P14Rik_+_85824456.23-P1P2                   58                    98
# 0610007P14Rik_+_85824523.23-P1P2                   65                   122
#
#                                   DMSO_CD11b_low_rep2  DMSO_CD11b_high_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                   63                   101
# 0610007P14Rik_+_85824469.23-P1P2                  105                   132
# 0610007P14Rik_+_85824478.23-P1P2                  268                   259
# 0610007P14Rik_+_85824456.23-P1P2                  107                   140
# 0610007P14Rik_+_85824523.23-P1P2                   65                    93
#
#                                   DMSO_GFP_low_rep1  DMSO_GFP_high_rep1  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                103                 126
# 0610007P14Rik_+_85824469.23-P1P2                134                 184
# 0610007P14Rik_+_85824478.23-P1P2                365                 523
# 0610007P14Rik_+_85824456.23-P1P2                113                 108
# 0610007P14Rik_+_85824523.23-P1P2                132                 172
#
#                                   DMSO_GFP_low_rep2  DMSO_GFP_high_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                208                 118
# 0610007P14Rik_+_85824469.23-P1P2                213                 148
# 0610007P14Rik_+_85824478.23-P1P2                536                 435
# 0610007P14Rik_+_85824456.23-P1P2                171                 148
# 0610007P14Rik_+_85824523.23-P1P2                150                 101
#
#                                   HU_CD11b_low_rep1  HU_CD11b_high_rep1  ...  \
# sgID                                                                     ...
# 0610007P14Rik_+_85824465.23-P1P2                118                 140  ...
# 0610007P14Rik_+_85824469.23-P1P2                126                 132  ...
# 0610007P14Rik_+_85824478.23-P1P2                348                 259  ...
# 0610007P14Rik_+_85824456.23-P1P2                109                 122  ...
# 0610007P14Rik_+_85824523.23-P1P2                 69                  94  ...
#
#                                   Day0_all_all_rep1  Day0_all_all_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                307                115
# 0610007P14Rik_+_85824469.23-P1P2                214                133
# 0610007P14Rik_+_85824478.23-P1P2                672                326
# 0610007P14Rik_+_85824456.23-P1P2                192                 87
# 0610007P14Rik_+_85824523.23-P1P2                234                119
#
#                                   DMSO_all_all_rep1  DMSO_all_all_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                167                136
# 0610007P14Rik_+_85824469.23-P1P2                172                206
# 0610007P14Rik_+_85824478.23-P1P2                430                400
# 0610007P14Rik_+_85824456.23-P1P2                102                101
# 0610007P14Rik_+_85824523.23-P1P2                132                139
#
#                                   HU_all_all_rep1  HU_all_all_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2              122              125
# 0610007P14Rik_+_85824469.23-P1P2              147              123
# 0610007P14Rik_+_85824478.23-P1P2              417              391
# 0610007P14Rik_+_85824456.23-P1P2              156              135
# 0610007P14Rik_+_85824523.23-P1P2              109              113
#
#                                   APH_all_all_rep1  APH_all_all_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                61               127
# 0610007P14Rik_+_85824469.23-P1P2               118               184
# 0610007P14Rik_+_85824478.23-P1P2               173               422
# 0610007P14Rik_+_85824456.23-P1P2                80               104
# 0610007P14Rik_+_85824523.23-P1P2                91               106
#
#                                   E2wd_all_all_rep1  E2wd_all_all_rep2
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                334                100
# 0610007P14Rik_+_85824469.23-P1P2                261                137
# 0610007P14Rik_+_85824478.23-P1P2                694                247
# 0610007P14Rik_+_85824456.23-P1P2                243                 74
# 0610007P14Rik_+_85824523.23-P1P2                187                 82
#
# [5 rows x 42 columns]

# %%
# Making a file for MAGECK:
gene_name = [x.split('_')[0] for x in counts_mageck.index]
counts_mageck["gene_name"] = gene_name
col_list = ["gene_name"]
col_list.extend(counts_mageck.columns[:42])

counts_mageck = counts_mageck[col_list]
counts_mageck.head()
# Out:
#                                       gene_name  DMSO_CD11b_low_rep1  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2  0610007P14Rik                  123
# 0610007P14Rik_+_85824469.23-P1P2  0610007P14Rik                  144
# 0610007P14Rik_+_85824478.23-P1P2  0610007P14Rik                  250
# 0610007P14Rik_+_85824456.23-P1P2  0610007P14Rik                   58
# 0610007P14Rik_+_85824523.23-P1P2  0610007P14Rik                   65
#
#                                   DMSO_CD11b_high_rep1  DMSO_CD11b_low_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                   120                   63
# 0610007P14Rik_+_85824469.23-P1P2                   152                  105
# 0610007P14Rik_+_85824478.23-P1P2                   302                  268
# 0610007P14Rik_+_85824456.23-P1P2                    98                  107
# 0610007P14Rik_+_85824523.23-P1P2                   122                   65
#
#                                   DMSO_CD11b_high_rep2  DMSO_GFP_low_rep1  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                   101                103
# 0610007P14Rik_+_85824469.23-P1P2                   132                134
# 0610007P14Rik_+_85824478.23-P1P2                   259                365
# 0610007P14Rik_+_85824456.23-P1P2                   140                113
# 0610007P14Rik_+_85824523.23-P1P2                    93                132
#
#                                   DMSO_GFP_high_rep1  DMSO_GFP_low_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                 126                208
# 0610007P14Rik_+_85824469.23-P1P2                 184                213
# 0610007P14Rik_+_85824478.23-P1P2                 523                536
# 0610007P14Rik_+_85824456.23-P1P2                 108                171
# 0610007P14Rik_+_85824523.23-P1P2                 172                150
#
#                                   DMSO_GFP_high_rep2  HU_CD11b_low_rep1  ...  \
# sgID                                                                     ...
# 0610007P14Rik_+_85824465.23-P1P2                 118                118  ...
# 0610007P14Rik_+_85824469.23-P1P2                 148                126  ...
# 0610007P14Rik_+_85824478.23-P1P2                 435                348  ...
# 0610007P14Rik_+_85824456.23-P1P2                 148                109  ...
# 0610007P14Rik_+_85824523.23-P1P2                 101                 69  ...
#
#                                   Day0_all_all_rep1  Day0_all_all_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                307                115
# 0610007P14Rik_+_85824469.23-P1P2                214                133
# 0610007P14Rik_+_85824478.23-P1P2                672                326
# 0610007P14Rik_+_85824456.23-P1P2                192                 87
# 0610007P14Rik_+_85824523.23-P1P2                234                119
#
#                                   DMSO_all_all_rep1  DMSO_all_all_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                167                136
# 0610007P14Rik_+_85824469.23-P1P2                172                206
# 0610007P14Rik_+_85824478.23-P1P2                430                400
# 0610007P14Rik_+_85824456.23-P1P2                102                101
# 0610007P14Rik_+_85824523.23-P1P2                132                139
#
#                                   HU_all_all_rep1  HU_all_all_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2              122              125
# 0610007P14Rik_+_85824469.23-P1P2              147              123
# 0610007P14Rik_+_85824478.23-P1P2              417              391
# 0610007P14Rik_+_85824456.23-P1P2              156              135
# 0610007P14Rik_+_85824523.23-P1P2              109              113
#
#                                   APH_all_all_rep1  APH_all_all_rep2  \
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                61               127
# 0610007P14Rik_+_85824469.23-P1P2               118               184
# 0610007P14Rik_+_85824478.23-P1P2               173               422
# 0610007P14Rik_+_85824456.23-P1P2                80               104
# 0610007P14Rik_+_85824523.23-P1P2                91               106
#
#                                   E2wd_all_all_rep1  E2wd_all_all_rep2
# sgID
# 0610007P14Rik_+_85824465.23-P1P2                334                100
# 0610007P14Rik_+_85824469.23-P1P2                261                137
# 0610007P14Rik_+_85824478.23-P1P2                694                247
# 0610007P14Rik_+_85824456.23-P1P2                243                 74
# 0610007P14Rik_+_85824523.23-P1P2                187                 82
#
# [5 rows x 43 columns]

# %%
counts_mageck.to_csv("../mageck/230408_bd354_counts_mageck.txt", sep='\t')

# %%
# negative control genes -- should just be a list
neg_ctrl = counts_mageck[counts_mageck["gene_name"] == "non-targeting"].index
neg_ctrl
# Out:
# Index(['non-targeting_00000', 'non-targeting_00001', 'non-targeting_00002',
#        'non-targeting_00003', 'non-targeting_00004', 'non-targeting_00005',
#        'non-targeting_00006', 'non-targeting_00007', 'non-targeting_00008',
#        'non-targeting_00009',
#        ...
#        'non-targeting_02160', 'non-targeting_02161', 'non-targeting_02162',
#        'non-targeting_02163', 'non-targeting_02164', 'non-targeting_02165',
#        'non-targeting_02166', 'non-targeting_02167', 'non-targeting_02168',
#        'non-targeting_02169'],
#       dtype='object', name='sgID', length=2170)

# %%
with open("230408_bd354_neg_ctrl_guides.txt", 'w') as ofile:
    for i in neg_ctrl:
        ofile.write(i + '\n')
