# %%
import pandas as pd
import numpy as np
from collections import Counter, defaultdict
import glob
import seaborn as sns
import gzip
import matplotlib.pyplot as plt

# %%
# weissman sgRNAs
library = pd.read_csv("TableS3_hCRISPRiv2_libraries.csv")

weissman_guides = [x.upper() for x in list(library["protospacer sequence"])]
library.head()
# Out:
#                     sgID  gene transcript  protospacer sequence  \
# 0  A1BG_-_58858617.23-P1  A1BG         P1  GGAGACCCAGCGCTAACCAG
# 1  A1BG_-_58858788.23-P1  A1BG         P1  GGGGCACCCAGGAGCGGTAG
# 2  A1BG_+_58858964.23-P1  A1BG         P1  GCTCCGGGCGACGTGGAGTG
# 3  A1BG_-_58858630.23-P1  A1BG         P1  GAACCAGGGGTGCCCAAGGG
# 4  A1BG_+_58858549.23-P1  A1BG         P1  GGCGAGGAACCGCCCAGCAA
#
#    selection rank  predicted score  empirical score  off-target stringency  \
# 0             1.0         1.008816              NaN                      0
# 1             2.0         0.901176              NaN                      0
# 2             3.0         0.836188              NaN                      0
# 3             4.0         0.827551              NaN                      0
# 4             5.0         0.775395              NaN                      0
#
#    CRISPRi-v2.1 predicted score Sublibrary Sublibrary half
# 0                      0.685071         h3            Top5
# 1                      0.782793         h3            Top5
# 2                      0.870837         h3            Top5
# 3                      0.590668         h3            Top5
# 4                      0.492280         h3            Top5

# %%
def get_lines(fn, counter, start_at_zero=False):
    i = 0
    with gzip.open(fn,'r') as fin:
        for line in fin:
            i += 1
            if ((i + 2) % 4 == 0): 
                if (i % 1000002 == 0):
                    print(i)
                # change the first letter to G because it's often read wrong
                # also read the first 20
                if not start_at_zero: seq = 'G' + line.rstrip()[1:20].decode() 
                else: seq = 'G' + line.rstrip()[:19].decode() 
                
                if seq not in counter: counter[seq] = 1
                else: counter[seq] += 1
        
    return(counter)

# get dictionary of reads for all files
def get_read_dict(fn1, fn2, fn3, fn4, fn5):
    print(fn1)
    counter = defaultdict(lambda: 0)
    
    counter = get_lines(fn1, counter)
    counter = get_lines(fn2, counter)
    counter = get_lines(fn3, counter)
    counter = get_lines(fn4, counter)
    counter = get_lines(fn5, counter, start_at_zero=True)  # these were from the third run where the first base is not G 

    
    return(dict(counter))

# %%
samples_to_dict = defaultdict(lambda: Counter())
for fn in glob.glob("raw_fastqs/*.gz"):
    cond = fn.replace("raw_fastqs/220311Van_D22-2700_NA_sequence_", "").replace(".fastq.gz", "")
    print(cond)
    samples_to_dict[cond] = get_lines(fn, samples_to_dict[cond], start_at_zero=False)
# Out:
# K562_BRQ_CD235a_High
# 1000002
# 3000006
# 5000010
# 7000014
# 9000018
# 11000022
# 13000026
# 15000030
# 17000034
# 19000038
# 21000042
# 23000046
# 25000050
# 27000054
# 29000058
# 31000062
# 33000066
# 35000070
# K562_BRQ_CD235a_Low
# 1000002
# 3000006
# 5000010
# 7000014
# 9000018
# 11000022
# 13000026
# 15000030
# 17000034
# 19000038
# 21000042
# 23000046
# 25000050
# 27000054
# 29000058
# 31000062
# 33000066
# 35000070
# 37000074
# K562_DMSO_CD235a_All
# 1000002
# 3000006
# 5000010
# 7000014
# 21000042
# 23000046
# 25000050
# 27000054
# 29000058
# 31000062
# 33000066
# 35000070
# THP-1___Pre
# 1000002
# 3000006
# 5000010
# 7000014
# 9000018
# 11000022
# 13000026
# 15000030
# 17000034
# 19000038
# 21000042
# 23000046
# 25000050
# 27000054
# 29000058
# 31000062
# 33000066
# 35000070
# 37000074

# %%
library["cts"] = guide_cts
library.head()
# Out:
#                     sgID  gene transcript  protospacer sequence  \
# 0  A1BG_-_58858617.23-P1  A1BG         P1  GGAGACCCAGCGCTAACCAG
# 1  A1BG_-_58858788.23-P1  A1BG         P1  GGGGCACCCAGGAGCGGTAG
# 2  A1BG_+_58858964.23-P1  A1BG         P1  GCTCCGGGCGACGTGGAGTG
# 3  A1BG_-_58858630.23-P1  A1BG         P1  GAACCAGGGGTGCCCAAGGG
# 4  A1BG_+_58858549.23-P1  A1BG         P1  GGCGAGGAACCGCCCAGCAA
#
#    selection rank  predicted score  empirical score  off-target stringency  \
# 0             1.0         1.008816              NaN                      0
# 1             2.0         0.901176              NaN                      0
# 2             3.0         0.836188              NaN                      0
# 3             4.0         0.827551              NaN                      0
# 4             5.0         0.775395              NaN                      0
#
#    CRISPRi-v2.1 predicted score Sublibrary Sublibrary half  cts
# 0                      0.685071         h3            Top5    0
# 1                      0.782793         h3            Top5    0
# 2                      0.870837         h3            Top5    0
# 3                      0.590668         h3            Top5    0
# 4                      0.492280         h3            Top5    0

# %%
library[library["gene"] == "CPSF1"]
# Out:
#                             sgID   gene transcript  protospacer sequence  \
# 39830  CPSF1_-_145634507.23-P1P2  CPSF1       P1P2  GTACATGGAGAACTCCAGAC
# 39831  CPSF1_-_145634725.23-P1P2  CPSF1       P1P2  GGACAGCAGCGAACTCAGTC
# 39832  CPSF1_-_145634704.23-P1P2  CPSF1       P1P2  GAGCCGACTCGAGAGGAACC
# 39833  CPSF1_+_145634667.23-P1P2  CPSF1       P1P2  GTCGGCTCCAACTGCCAGGT
# 39834  CPSF1_-_145634697.23-P1P2  CPSF1       P1P2  GCAGTTGGAGCCGACTCGAG
# 39835  CPSF1_-_145634511.23-P1P2  CPSF1       P1P2  GTGGAGAACTCCAGACCGGT
# 39836  CPSF1_+_145634685.23-P1P2  CPSF1       P1P2  GGTCCCGGTTCCTCTCGAGT
# 39837  CPSF1_+_145634671.23-P1P2  CPSF1       P1P2  GCGAGTCGGCTCCAACTGCC
# 39838  CPSF1_-_145634203.23-P1P2  CPSF1       P1P2  GCTTCCCGGTGGGGTAGGAa
# 39839  CPSF1_+_145634659.23-P1P2  CPSF1       P1P2  GAACTGCCAGGTgggcggcc
#
#        selection rank  predicted score  empirical score  \
# 39830             1.0              NaN         1.149905
# 39831             2.0              NaN         0.977292
# 39832             3.0         0.822700         0.807319
# 39833             4.0         0.882392              NaN
# 39834             5.0         0.824519              NaN
# 39835             6.0         0.779970              NaN
# 39836             7.0         0.774557              NaN
# 39837             8.0         0.742082              NaN
# 39838             9.0         0.718066              NaN
# 39839            10.0         0.651736              NaN
#
#        off-target stringency  CRISPRi-v2.1 predicted score Sublibrary  \
# 39830                      0                      0.761732         h4
# 39831                      0                      0.695598         h4
# 39832                      0                      0.873691         h4
# 39833                      0                      0.889822         h4
# 39834                      0                      0.909527         h4
# 39835                      0                      0.754372         h4
# 39836                      0                      0.861061         h4
# 39837                      0                      0.698324         h4
# 39838                      0                      0.443279         h4
# 39839                      0                      0.653253         h4
#
#       Sublibrary half   cts
# 39830            Top5   497
# 39831            Top5   460
# 39832            Top5   653
# 39833            Top5   646
# 39834            Top5   374
# 39835           Supp5   736
# 39836           Supp5   888
# 39837           Supp5  1008
# 39838           Supp5   653
# 39839           Supp5   908

# %%
import pickle
pickle.dump(samples_to_dict, open("230727_bd246_mapping.pkl", "wb"))
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-65-09a2856fc3fa> in <module>
#       1 import pickle
# ----> 2 pickle.dump(samples_to_dict, open("230727_bd246_mapping.pkl", "wb"))
#
# PicklingError: Can't pickle <function <lambda> at 0x7f6225947b90>: attribute lookup <lambda> on __main__ failed

# %%
samples_to_dict['K562_BRQ_CD235a_High']
# Out:
# Counter({'GCCCANGAGCCCGACTTCAA': 1,
#          'GACGCNGCCCCACCATAGAG': 2,
#          'GCCTCNGCGAGACCACCCGT': 1,
#          'GCCGGNACCGGTGTCCCCGA': 1,
#          'GGCCCNCGCGTGCCAGCCGA': 1,
#          'GTGCCNACACTGACCCCGTG': 2,
#          'GTTTCCAGAGGGATATCCTA': 560,
#          'GCCCAGCGGCCCCGGTCCCG': 283,
#          'GACTCATGCACTCACGGCCA': 533,
#          'GGACCAGTCGGCGATCCCAA': 572,
#          'GGCCATGCACCCAGTCTTCG': 648,
#          'GTGGGCCGGCCCGAAGGTGG': 646,
#          'GCGGAGAACAATATGGCGGA': 297,
#          'GCCAGGTGCTCGGAGAAACC': 391,
#          'GGACGCCAGAGAGACTCGTG': 640,
#          'GACCAGGATGGGCACCACCC': 138439,
#          'GCGGCCGGGGACTGACGGTA': 478,
#          'GGGCCAGGAATAAAGGATCT': 513,
#          'GCGAGGCGCGTAAGTGGGGG': 539,
#          'GTGTACCCTGCTACTCCTGA': 577,
#          'GGCCCGACCCCACGCCAAGA': 624,
#          'GTGGCGTCGGTCCCTCGGTC': 661,
#          'GCCAAGCCCCGCAGCTACGG': 688,
#          'GGCTCTCCCCGCGTCCAAGA': 643,
#          'GGCTCCCAAGGCCTCTACGT': 434,
#          'GAGCGCAAGCAGCGGGTTAG': 669,
#          'GGCGGCGGCGTGTCTCGGCC': 677,
#          'GTTCCAGCTAGCATGCCGCA': 814,
#          'GACGTCTGTGCGGCTGCGTG': 843,
#          'GTCGGCTGGTCCCAGTCCCC': 867,
#          'GCTGCTGGCGGTCGGGCGCT': 334,
#          'GGGTTTCTAAGGGACTAACT': 429,
#          'GATGAGTCCTCAGTGCCGGC': 511,
#          'GCAGCTCGGGGCCGAGGGTA': 650,
#          'GTTGCTTAGAGAAGGAAATT': 489,
#          'GCTCTGCGAGCAGAGGACAC': 352,
#          'GTACCTGGTGGAGGCGGCTC': 475,
#          'GTCAAAGTAAAAATACCAGT': 301,
#          'GGCTGCTAGGACGCTGGCGT': 694,
#          'GACGACGGAGAAACCGAGAA': 838,
#          'GGATCGTCCTCAAGATAGTG': 497,
#          'GTCATGGGCAGCCAGTGATT': 950,
#          'GGGACTCGCACAGCTCCCGG': 711,
#          'GCGCGCGGCCCTGCGTGAGG': 604,
#          'GTCCAGGAGCCAAACTCCCT': 616,
#          'GTGAGAAGACCGGTCGGCCT': 1053,
#          'GAGCGGCTTCCGGGATATGG': 687,
#          'GGAGCTGACTCGCTGGACTT': 1,
#          'GGGACAGGTGGGCCCCTAAG': 346,
#          'GCATACATAAGCACAGACAT': 419,
#          'GAGCAGCCCTCATAGTGCCG': 1072,
#          'GAGCCAGGTTGGCAGCTGAC': 304,
#          'GACACGCACAGCGAGCTTCG': 590,
#          'GGAGCGCCTGTCCCTCCAAA': 565,
#          'GGCTGGCTGTGTTCTTACAA': 448,
#          'GACAGCGTGACTACAGGGTA': 280,
#          'GAGGGACAGTGGCCGGGCCA': 423,
#          'GTAAAACGGACACGCGACAA': 313,
#          'GTGCGGTGCAGCGTCGGCCG': 623,
#          'GGTTTAACTTTTGTGCTTCT': 879,
#          'GGAGGTGTTGATCCTCAGGG': 397,
#          'GGCAGCTAAAACCCATCTCA': 786,
#          'GCCGCCACTACAGCTATACG': 451,
#          'GCTGGCTCCAGGCTCGACAC': 260,
#          'GCGGGGCCGAGCAGCCTCTG': 906,
#          'GTGCCCTGCCCACTAGGTCA': 651,
#          'GTCGCACGCAGCTCCAGGCG': 365,
#          'GAGGAGCTCGGCCGAGTGGA': 888,
#          'GCAACCCAGTCTCCCTGTGA': 938,
#          'GGTTCTGACACCCTCAGACA': 369,
#          'GCCTGCGCGAGCAAGTGGGG': 158,
#          'GCAAGCAGGTAAGACGTGAA': 733,
#          'GTCAGAGGTGGCTACAGGGC': 499,
#          'GGCCATAACTATTAGGTGGA': 355,
#          'GCCGCCGCCGCCTACCATCG': 519,
#          'GGCCCCGTGACGTCCCTCCA': 655,
#          'GAAAAATGAGCTGTCAAATT': 426,
#          'GAGTAAGGCCTCCTCCTCGT': 784,
#          'GGAGTGCGGGCCTGGGACCA': 758,
#          'GGAGAGATGGGTAATTGGAA': 466,
#          'GCCGCGGCCGGGGCTCCGAG': 710,
#          'GGACGGCCGAGACGTGGGGA': 806,
#          'GACTGAACTACCCCCATCTA': 616,
#          'GGACGCACGGGGACACCCTC': 546,
#          'GCAATGTGCAAGTTGAACCA': 365,
#          'GACGTGCGTCGGACAGGTCA': 1,
#          'GGGAACATCTCGTCCACCGC': 364,
#          'GGAGGCCTGAGCGCGCGGAG': 457,
#          'GACCAGCCGGGGTCACGTCC': 823,
#          'GAGAGACTCCGCAGCGTACG': 654,
#          'GATGCCTAGACCGCAGCCAG': 591,
#          'GTAAGAACCAGAGCCTACTC': 1,
#          'GCCCGAGCCGCGAAGAACCG': 181,
#          'GGCCCCCAGCCGCGGGTCAC': 1,
#          'GACGAAGACAGTCACACAAC': 1,
#          'GAGTTGGCGTGCTAGTGGGA': 310,
#          'GCGTCGCGCCTGGGAGAAGA': 520,
#          'GTCCCTCCGGAAGACCCCGG': 558,
#          'GCCATGACCCTCTAGAAGAC': 365,
#          'GCAAGGAAGCGGAAGCGGAG': 430,
#          'GGCCATCTGCCGCCACCGTC': 523,
#          'GTCGGGGACTGCGGACTGTG': 580,
#          'GGAATCTCACGCGCCGCTGA': 1,
#          'GAGCTCTATGGAGGTGGCAG': 103,
#          'GCCCTCCCTCCGGAAGACCC': 546,
#          'GGTCCTAGGGCTGGTGGACA': 446,
#          'GTCCACCGGCAACTTGACTA': 586,
#          'GCGGAAGCGGCCGCAAGAGG': 584,
#          'GACAAGGCAAATGCTAGATG': 771,
#          'GGGAAGGAGCGGCTCGGTGT': 505,
#          'GATGGGGCTTCTTCAGGCGG': 631,
#          'GGCTCCCTTGCTCGAACTGT': 570,
#          'GGCCCCTGCGCCATCCCGGG': 706,
#          'GGCTGCTGTGCAGTTGTCCG': 844,
#          'GGACTCTGGGCTCGCAGCGG': 511,
#          'GCCCCGGCGCCGCGCGAAGT': 477,
#          'GAACTATCCGCAGGGACTCG': 367,
#          'GTTCATGGAAAAGAGCACCA': 486,
#          'GACAGACCATCCACTAAAAG': 1,
#          'GGGCACACGAGACTGAGCAG': 811,
#          'GGCGGCGGAGGCGTCGAAAA': 445,
#          'GCGCCGCCGCAGGCAGCAGA': 389,
#          'GTCACATGGTGTTGGCTGTA': 657,
#          'GCCGCTGCGGACCACCTTCA': 701,
#          'GTTTGGAGTCTACTGCAGGG': 561,
#          'GCCCGGCGGAAAACCGAAGT': 311,
#          'GGCGCGGGCAAGTCCCCCCG': 830,
#          'GCCAGTTTGAGGAGACTCAT': 262,
#          'GGGGCTTAGGACAGGTCCCG': 558,
#          'GCGAGGCAAATACCCAGCCC': 554,
#          'GTCCATGGGCAACACTGCAG': 816,
#          'GCGAGGCGGTTGGCGGGGGC': 438,
#          'GATGGGAGTGTGGCCTGTGA': 599,
#          'GGGGCTGTGGGGTGATGTAG': 565,
#          'GACTGGCCTGCAGCAGTGAG': 560,
#          'GGTTTGTATTGCTATAATTT': 813,
#          'GCCCGACGGCGCAGAGTCTG': 531,
#          'GTCGGCCACCCCAGAAGCCT': 817,
#          'GAGCAGCTGGAGGCGGTGAA': 521,
#          'GTAGTTCGCGCGGCCGTCCT': 896,
#          'GTGAACTGAGGGCGGTGAGG': 555,
#          'GGCAGCAGCAACTTTCGCGG': 792,
#          'GTGCCCAGTCCCCTCATCAA': 804,
#          'GTCACGAGCTGGAGCCCAAG': 669,
#          'GCGGCCCGATGAAGTCATCC': 408,
#          'GCTGCCGGGTCACATCTCCG': 793,
#          'GGGGTCAGAAGGCAGCGCGG': 400,
#          'GGGGAAGGTAAGTCCAGTCT': 655,
#          'GCGGTTTTCAGCCTCTTTCC': 830,
#          'GCAGGATTGCGGGTAAGTGC': 757,
#          'GCGCGTCTGGCCCCGCTCTA': 183,
#          'GCCGTGCCTGCCGTCCAGGG': 589,
#          'GCGCTCCGGGTGGGAATGGC': 401,
#          'GAGGAAACCGCTCCCGAGAG': 157,
#          'GGCCCCTAGGTGGCTTCCTG': 403,
#          'GCGAGGTGCCCAGCCCGCAC': 774,
#          'GAGCGTGGTCATGCAGGTGA': 550,
#          'GCTGCAGGCAAGCTTTTCTG': 329,
#          'GGCGCGCGGCGGGAGACCCA': 894,
#          'GAAGCACTCGGGCCGACCCG': 299,
#          'GTTGGGGCCGCGGACTTTGG': 595,
#          'GGCCCGGGCTGAAACAGCAA': 588,
#          'GGCGCGTTTGGGAGCATAGT': 95,
#          'GGTGTAATCAGGGCGAAAGA': 480,
#          'GTCTAGAAAAGCGGCGGCAG': 216,
#          'GCCGGCCGGGCGGGGAAGAC': 491,
#          'GACCCGGGAAAACAGCTCCC': 559,
#          'GATCGCCGGGAGGGCGGTTG': 772,
#          'GCCAAGTGCGCTGTGCTCGA': 477,
#          'GTCGCGGAGAGGGAAGAATA': 387,
#          'GGGACTCGCGGCGGTCGCCC': 781,
#          'GGGCACTGTCCACCGACGAG': 501,
#          'GAGGACACCTGGAGCGCTGG': 423,
#          'GACCAGTCCGGACTTGAGGC': 897,
#          'GGCTCCGCGATCGGCTCTGT': 255,
#          'GCGTGCGGTAACGCGTGGTC': 646,
#          'GACCCAGCCACGCTCTAGGG': 753,
#          'GCGGGTCGGACTCTTCGGAA': 626,
#          'GGAGGGAGCATGGAGACCGT': 1,
#          'GTCACGCGGTGAGTCATATG': 586,
#          'GCGGCTGCTCCTCAGGGAGT': 497,
#          'GGGCACGGTGAGTACCCGGG': 791,
#          'GCGCCGGCCGGCCTAGAGCT': 390,
#          'GTTAAGCCTAGCCTTCAAAC': 391,
#          'GTCGCAGCTGGCTCTAGTGC': 568,
#          'GTGGGCCTGCTGAGACCGGA': 522,
#          'GGCTGAAACCCTAGGTCCCA': 410,
#          'GCTGAGGGCCCGTACCCCGG': 574,
#          'GGCCTGCCCTTTAGTATTTA': 408,
#          'GTTGCAGTAGGCATGGTCCT': 580,
#          ...})

# %%
# a dict of count vectors
sample_to_counts = {}
for i in list(samples_to_dict.keys())[:34]:
    sample_to_counts[i] = [samples_to_dict[i].get(k, 0) for k in weissman_guides]

# %%
counts = pd.DataFrame.from_dict(sample_to_counts)
counts.index = library["sgID"]
counts.columns = list(samples_to_dict.keys())[:34]

counts.to_csv("230727_bd246_sgrna_counts.csv")
counts.head()
# Out:
#                        K562_BRQ_CD235a_High  K562_BRQ_CD235a_Low  \
# sgID
# A1BG_-_58858617.23-P1                     0                    0
# A1BG_-_58858788.23-P1                     0                    0
# A1BG_+_58858964.23-P1                     0                    0
# A1BG_-_58858630.23-P1                     0                    0
# A1BG_+_58858549.23-P1                     0                    0
#
#                        K562_DMSO_CD235a_All  K562_DMSO_CD235a_High  \
# sgID
# A1BG_-_58858617.23-P1                     0                      0
# A1BG_-_58858788.23-P1                     0                      0
# A1BG_+_58858964.23-P1                     0                      0
# A1BG_-_58858630.23-P1                     0                      0
# A1BG_+_58858549.23-P1                     0                      0
#
#                        K562_DMSO_CD235a_Low  K562_DMSO_CD61_All  \
# sgID
# A1BG_-_58858617.23-P1                     0                   0
# A1BG_-_58858788.23-P1                     0                   0
# A1BG_+_58858964.23-P1                     0                   0
# A1BG_-_58858630.23-P1                     0                   0
# A1BG_+_58858549.23-P1                     0                   0
#
#                        K562_DMSO_CD61_High  K562_DMSO_CD61_Low  \
# sgID
# A1BG_-_58858617.23-P1                    0                   0
# A1BG_-_58858788.23-P1                    0                   0
# A1BG_+_58858964.23-P1                    0                   0
# A1BG_-_58858630.23-P1                    0                   0
# A1BG_+_58858549.23-P1                    0                   0
#
#                        K562_HU_CD235a_All  K562_HU_CD235a_High  ...  \
# sgID                                                            ...
# A1BG_-_58858617.23-P1                   0                    0  ...
# A1BG_-_58858788.23-P1                   0                    0  ...
# A1BG_+_58858964.23-P1                   0                    0  ...
# A1BG_-_58858630.23-P1                   0                    0  ...
# A1BG_+_58858549.23-P1                   0                    0  ...
#
#                        THP-1_DMSO_CD14_Low  THP-1_HU_CD11b_All  \
# sgID
# A1BG_-_58858617.23-P1                    0                   0
# A1BG_-_58858788.23-P1                    0                   0
# A1BG_+_58858964.23-P1                    0                   0
# A1BG_-_58858630.23-P1                    0                   0
# A1BG_+_58858549.23-P1                    0                   0
#
#                        THP-1_HU_CD11b_High  THP-1_HU_CD11b_Low  \
# sgID
# A1BG_-_58858617.23-P1                    0                   0
# A1BG_-_58858788.23-P1                    0                   0
# A1BG_+_58858964.23-P1                    0                   0
# A1BG_-_58858630.23-P1                    0                   0
# A1BG_+_58858549.23-P1                    0                   0
#
#                        THP-1_HU_CD14_All  THP-1_HU_CD14_High  \
# sgID
# A1BG_-_58858617.23-P1                  0                   0
# A1BG_-_58858788.23-P1                  0                   0
# A1BG_+_58858964.23-P1                  0                   0
# A1BG_-_58858630.23-P1                  0                   0
# A1BG_+_58858549.23-P1                  0                   0
#
#                        THP-1_HU_CD14_Low  THP-1_PMA_CD14_High  \
# sgID
# A1BG_-_58858617.23-P1                  0                    0
# A1BG_-_58858788.23-P1                  0                    0
# A1BG_+_58858964.23-P1                  0                    0
# A1BG_-_58858630.23-P1                  0                    0
# A1BG_+_58858549.23-P1                  0                    0
#
#                        THP-1_PMA_CD14_Low  THP-1___Pre
# sgID
# A1BG_-_58858617.23-P1                   0            0
# A1BG_-_58858788.23-P1                   0            0
# A1BG_+_58858964.23-P1                   0            0
# A1BG_-_58858630.23-P1                   0            0
# A1BG_+_58858549.23-P1                   0            0
#
# [5 rows x 34 columns]

# %%
counts_valid = counts[counts.sum(axis=1) > 10]
counts_valid.to_csv("230727_bd246_sgrna_counts_validonly.csv")

counts_valid
# Out:
#                          K562_BRQ_CD235a_High  K562_BRQ_CD235a_Low  \
# sgID
# AAAS_-_53715438.23-P1P2                  4431                 4124
# AAAS_+_53715355.23-P1P2                   624                  787
# AAAS_-_53715389.23-P1P2                   621                  719
# AAAS_+_53714983.23-P1P2                   363                  223
# AAAS_-_53715371.23-P1P2                   767                  470
# ...                                       ...                  ...
# non-targeting_03742                       395                  405
# non-targeting_03745                       556                  586
# non-targeting_03755                       523                  661
# non-targeting_03772                       521                  442
# non-targeting_03788                       273                  293
#
#                          K562_DMSO_CD235a_All  K562_DMSO_CD235a_High  \
# sgID
# AAAS_-_53715438.23-P1P2                  6068                   4822
# AAAS_+_53715355.23-P1P2                   824                    824
# AAAS_-_53715389.23-P1P2                   545                    692
# AAAS_+_53714983.23-P1P2                   511                    436
# AAAS_-_53715371.23-P1P2                   628                    813
# ...                                       ...                    ...
# non-targeting_03742                       601                    637
# non-targeting_03745                       750                    798
# non-targeting_03755                       610                    363
# non-targeting_03772                       659                    622
# non-targeting_03788                       362                    386
#
#                          K562_DMSO_CD235a_Low  K562_DMSO_CD61_All  \
# sgID
# AAAS_-_53715438.23-P1P2                  4258                4806
# AAAS_+_53715355.23-P1P2                   660                 818
# AAAS_-_53715389.23-P1P2                   656                 481
# AAAS_+_53714983.23-P1P2                   483                 511
# AAAS_-_53715371.23-P1P2                   667                 501
# ...                                       ...                 ...
# non-targeting_03742                       652                 328
# non-targeting_03745                       813                 629
# non-targeting_03755                       587                 608
# non-targeting_03772                       608                 698
# non-targeting_03788                       386                 336
#
#                          K562_DMSO_CD61_High  K562_DMSO_CD61_Low  \
# sgID
# AAAS_-_53715438.23-P1P2                 3580                4088
# AAAS_+_53715355.23-P1P2                  501                 494
# AAAS_-_53715389.23-P1P2                  369                 407
# AAAS_+_53714983.23-P1P2                  320                 300
# AAAS_-_53715371.23-P1P2                  450                 333
# ...                                      ...                 ...
# non-targeting_03742                      268                 284
# non-targeting_03745                      575                 474
# non-targeting_03755                      471                 380
# non-targeting_03772                      446                 409
# non-targeting_03788                      311                 341
#
#                          K562_HU_CD235a_All  K562_HU_CD235a_High  ...  \
# sgID                                                              ...
# AAAS_-_53715438.23-P1P2                4731                 6100  ...
# AAAS_+_53715355.23-P1P2                 675                  954  ...
# AAAS_-_53715389.23-P1P2                 631                 1031  ...
# AAAS_+_53714983.23-P1P2                 335                  686  ...
# AAAS_-_53715371.23-P1P2                 494                  419  ...
# ...                                     ...                  ...  ...
# non-targeting_03742                     555                  552  ...
# non-targeting_03745                     591                  723  ...
# non-targeting_03755                     701                  638  ...
# non-targeting_03772                     451                  888  ...
# non-targeting_03788                     296                  431  ...
#
#                          THP-1_DMSO_CD14_Low  THP-1_HU_CD11b_All  \
# sgID
# AAAS_-_53715438.23-P1P2                 2970                2410
# AAAS_+_53715355.23-P1P2                  490                 417
# AAAS_-_53715389.23-P1P2                  362                 343
# AAAS_+_53714983.23-P1P2                  423                 213
# AAAS_-_53715371.23-P1P2                  351                 185
# ...                                      ...                 ...
# non-targeting_03742                      381                 279
# non-targeting_03745                      509                 308
# non-targeting_03755                      471                 336
# non-targeting_03772                      408                 354
# non-targeting_03788                      155                 220
#
#                          THP-1_HU_CD11b_High  THP-1_HU_CD11b_Low  \
# sgID
# AAAS_-_53715438.23-P1P2                 1113                3961
# AAAS_+_53715355.23-P1P2                  357                 533
# AAAS_-_53715389.23-P1P2                  168                 517
# AAAS_+_53714983.23-P1P2                  198                 329
# AAAS_-_53715371.23-P1P2                  120                 425
# ...                                      ...                 ...
# non-targeting_03742                      239                 372
# non-targeting_03745                      244                 373
# non-targeting_03755                      239                 360
# non-targeting_03772                      233                 339
# non-targeting_03788                      197                 303
#
#                          THP-1_HU_CD14_All  THP-1_HU_CD14_High  \
# sgID
# AAAS_-_53715438.23-P1P2               2226                1879
# AAAS_+_53715355.23-P1P2                429                 359
# AAAS_-_53715389.23-P1P2                300                 156
# AAAS_+_53714983.23-P1P2                215                 275
# AAAS_-_53715371.23-P1P2                325                 208
# ...                                    ...                 ...
# non-targeting_03742                    278                 376
# non-targeting_03745                    408                 368
# non-targeting_03755                    273                 323
# non-targeting_03772                    275                 241
# non-targeting_03788                    140                 192
#
#                          THP-1_HU_CD14_Low  THP-1_PMA_CD14_High  \
# sgID
# AAAS_-_53715438.23-P1P2               2687                 3917
# AAAS_+_53715355.23-P1P2                401                  700
# AAAS_-_53715389.23-P1P2                329                  779
# AAAS_+_53714983.23-P1P2                206                  201
# AAAS_-_53715371.23-P1P2                350                  365
# ...                                    ...                  ...
# non-targeting_03742                    330                  387
# non-targeting_03745                    369                  749
# non-targeting_03755                    342                  447
# non-targeting_03772                    318                  566
# non-targeting_03788                    206                  226
#
#                          THP-1_PMA_CD14_Low  THP-1___Pre
# sgID
# AAAS_-_53715438.23-P1P2                4397         3965
# AAAS_+_53715355.23-P1P2                 597          719
# AAAS_-_53715389.23-P1P2                 410          466
# AAAS_+_53714983.23-P1P2                 362          453
# AAAS_-_53715371.23-P1P2                 364          436
# ...                                     ...          ...
# non-targeting_03742                     403          593
# non-targeting_03745                     825          636
# non-targeting_03755                     508          587
# non-targeting_03772                     438          544
# non-targeting_03788                     308          323
#
# [18499 rows x 34 columns]

# %% [markdown]
# ## MAGECK

# %%
counts_mageck = pd.read_csv("230727_bd246_sgrna_counts_validonly.csv", index_col=0)
counts_mageck.head()
# Out:
#                          K562_BRQ_CD235a_High  K562_BRQ_CD235a_Low  \
# sgID
# AAAS_-_53715438.23-P1P2                  4431                 4124
# AAAS_+_53715355.23-P1P2                   624                  787
# AAAS_-_53715389.23-P1P2                   621                  719
# AAAS_+_53714983.23-P1P2                   363                  223
# AAAS_-_53715371.23-P1P2                   767                  470
#
#                          K562_DMSO_CD235a_All  K562_DMSO_CD235a_High  \
# sgID
# AAAS_-_53715438.23-P1P2                  6068                   4822
# AAAS_+_53715355.23-P1P2                   824                    824
# AAAS_-_53715389.23-P1P2                   545                    692
# AAAS_+_53714983.23-P1P2                   511                    436
# AAAS_-_53715371.23-P1P2                   628                    813
#
#                          K562_DMSO_CD235a_Low  K562_DMSO_CD61_All  \
# sgID
# AAAS_-_53715438.23-P1P2                  4258                4806
# AAAS_+_53715355.23-P1P2                   660                 818
# AAAS_-_53715389.23-P1P2                   656                 481
# AAAS_+_53714983.23-P1P2                   483                 511
# AAAS_-_53715371.23-P1P2                   667                 501
#
#                          K562_DMSO_CD61_High  K562_DMSO_CD61_Low  \
# sgID
# AAAS_-_53715438.23-P1P2                 3580                4088
# AAAS_+_53715355.23-P1P2                  501                 494
# AAAS_-_53715389.23-P1P2                  369                 407
# AAAS_+_53714983.23-P1P2                  320                 300
# AAAS_-_53715371.23-P1P2                  450                 333
#
#                          K562_HU_CD235a_All  K562_HU_CD235a_High  ...  \
# sgID                                                              ...
# AAAS_-_53715438.23-P1P2                4731                 6100  ...
# AAAS_+_53715355.23-P1P2                 675                  954  ...
# AAAS_-_53715389.23-P1P2                 631                 1031  ...
# AAAS_+_53714983.23-P1P2                 335                  686  ...
# AAAS_-_53715371.23-P1P2                 494                  419  ...
#
#                          THP-1_DMSO_CD14_Low  THP-1_HU_CD11b_All  \
# sgID
# AAAS_-_53715438.23-P1P2                 2970                2410
# AAAS_+_53715355.23-P1P2                  490                 417
# AAAS_-_53715389.23-P1P2                  362                 343
# AAAS_+_53714983.23-P1P2                  423                 213
# AAAS_-_53715371.23-P1P2                  351                 185
#
#                          THP-1_HU_CD11b_High  THP-1_HU_CD11b_Low  \
# sgID
# AAAS_-_53715438.23-P1P2                 1113                3961
# AAAS_+_53715355.23-P1P2                  357                 533
# AAAS_-_53715389.23-P1P2                  168                 517
# AAAS_+_53714983.23-P1P2                  198                 329
# AAAS_-_53715371.23-P1P2                  120                 425
#
#                          THP-1_HU_CD14_All  THP-1_HU_CD14_High  \
# sgID
# AAAS_-_53715438.23-P1P2               2226                1879
# AAAS_+_53715355.23-P1P2                429                 359
# AAAS_-_53715389.23-P1P2                300                 156
# AAAS_+_53714983.23-P1P2                215                 275
# AAAS_-_53715371.23-P1P2                325                 208
#
#                          THP-1_HU_CD14_Low  THP-1_PMA_CD14_High  \
# sgID
# AAAS_-_53715438.23-P1P2               2687                 3917
# AAAS_+_53715355.23-P1P2                401                  700
# AAAS_-_53715389.23-P1P2                329                  779
# AAAS_+_53714983.23-P1P2                206                  201
# AAAS_-_53715371.23-P1P2                350                  365
#
#                          THP-1_PMA_CD14_Low  THP-1___Pre
# sgID
# AAAS_-_53715438.23-P1P2                4397         3965
# AAAS_+_53715355.23-P1P2                 597          719
# AAAS_-_53715389.23-P1P2                 410          466
# AAAS_+_53714983.23-P1P2                 362          453
# AAAS_-_53715371.23-P1P2                 364          436
#
# [5 rows x 34 columns]

# %%
col_list
# Out:
# ['gene_name',
#  'K562_BRQ_CD235a_Low',
#  'K562_DMSO_CD235a_All',
#  'K562_DMSO_CD235a_High',
#  'K562_DMSO_CD235a_Low',
#  'K562_DMSO_CD61_All',
#  'K562_DMSO_CD61_High',
#  'K562_DMSO_CD61_Low',
#  'K562_HU_CD235a_All',
#  'K562_HU_CD235a_High',
#  'K562_HU_CD235a_Low',
#  'K562_PMA_CD235a_High',
#  'K562_PMA_CD235a_Low',
#  'K562___Pre',
#  'THP-1_BRQ_CD11b_All',
#  'THP-1_BRQ_CD11b_High',
#  'THP-1_BRQ_CD11b_Low',
#  'THP-1_BRQ_CD14_High',
#  'THP-1_BRQ_CD14_Low',
#  'THP-1_DMSO_CD11b_All',
#  'THP-1_DMSO_CD11b_High',
#  'THP-1_DMSO_CD11b_Low',
#  'THP-1_DMSO_CD14_All',
#  'THP-1_DMSO_CD14_High',
#  'THP-1_DMSO_CD14_Low',
#  'THP-1_HU_CD11b_All',
#  'THP-1_HU_CD11b_High',
#  'THP-1_HU_CD11b_Low',
#  'THP-1_HU_CD14_All',
#  'THP-1_HU_CD14_High',
#  'THP-1_HU_CD14_Low',
#  'THP-1_PMA_CD14_High',
#  'THP-1_PMA_CD14_Low',
#  'THP-1___Pre']

# %%
# Making a file for MAGECK:
gene_name = [x.split('_')[0] for x in counts_mageck.index]
counts_mageck["gene_name"] = gene_name
col_list = ["gene_name"]
col_list.extend(counts_mageck.columns[:34])

counts_mageck = counts_mageck[col_list]
counts_mageck.head()
# Out:
#                         gene_name  K562_BRQ_CD235a_High  K562_BRQ_CD235a_Low  \
# sgID
# AAAS_-_53715438.23-P1P2      AAAS                  4431                 4124
# AAAS_+_53715355.23-P1P2      AAAS                   624                  787
# AAAS_-_53715389.23-P1P2      AAAS                   621                  719
# AAAS_+_53714983.23-P1P2      AAAS                   363                  223
# AAAS_-_53715371.23-P1P2      AAAS                   767                  470
#
#                          K562_DMSO_CD235a_All  K562_DMSO_CD235a_High  \
# sgID
# AAAS_-_53715438.23-P1P2                  6068                   4822
# AAAS_+_53715355.23-P1P2                   824                    824
# AAAS_-_53715389.23-P1P2                   545                    692
# AAAS_+_53714983.23-P1P2                   511                    436
# AAAS_-_53715371.23-P1P2                   628                    813
#
#                          K562_DMSO_CD235a_Low  K562_DMSO_CD61_All  \
# sgID
# AAAS_-_53715438.23-P1P2                  4258                4806
# AAAS_+_53715355.23-P1P2                   660                 818
# AAAS_-_53715389.23-P1P2                   656                 481
# AAAS_+_53714983.23-P1P2                   483                 511
# AAAS_-_53715371.23-P1P2                   667                 501
#
#                          K562_DMSO_CD61_High  K562_DMSO_CD61_Low  \
# sgID
# AAAS_-_53715438.23-P1P2                 3580                4088
# AAAS_+_53715355.23-P1P2                  501                 494
# AAAS_-_53715389.23-P1P2                  369                 407
# AAAS_+_53714983.23-P1P2                  320                 300
# AAAS_-_53715371.23-P1P2                  450                 333
#
#                          K562_HU_CD235a_All  ...  THP-1_DMSO_CD14_Low  \
# sgID                                         ...
# AAAS_-_53715438.23-P1P2                4731  ...                 2970
# AAAS_+_53715355.23-P1P2                 675  ...                  490
# AAAS_-_53715389.23-P1P2                 631  ...                  362
# AAAS_+_53714983.23-P1P2                 335  ...                  423
# AAAS_-_53715371.23-P1P2                 494  ...                  351
#
#                          THP-1_HU_CD11b_All  THP-1_HU_CD11b_High  \
# sgID
# AAAS_-_53715438.23-P1P2                2410                 1113
# AAAS_+_53715355.23-P1P2                 417                  357
# AAAS_-_53715389.23-P1P2                 343                  168
# AAAS_+_53714983.23-P1P2                 213                  198
# AAAS_-_53715371.23-P1P2                 185                  120
#
#                          THP-1_HU_CD11b_Low  THP-1_HU_CD14_All  \
# sgID
# AAAS_-_53715438.23-P1P2                3961               2226
# AAAS_+_53715355.23-P1P2                 533                429
# AAAS_-_53715389.23-P1P2                 517                300
# AAAS_+_53714983.23-P1P2                 329                215
# AAAS_-_53715371.23-P1P2                 425                325
#
#                          THP-1_HU_CD14_High  THP-1_HU_CD14_Low  \
# sgID
# AAAS_-_53715438.23-P1P2                1879               2687
# AAAS_+_53715355.23-P1P2                 359                401
# AAAS_-_53715389.23-P1P2                 156                329
# AAAS_+_53714983.23-P1P2                 275                206
# AAAS_-_53715371.23-P1P2                 208                350
#
#                          THP-1_PMA_CD14_High  THP-1_PMA_CD14_Low  THP-1___Pre
# sgID
# AAAS_-_53715438.23-P1P2                 3917                4397         3965
# AAAS_+_53715355.23-P1P2                  700                 597          719
# AAAS_-_53715389.23-P1P2                  779                 410          466
# AAAS_+_53714983.23-P1P2                  201                 362          453
# AAAS_-_53715371.23-P1P2                  365                 364          436
#
# [5 rows x 35 columns]

# %%
d = dict(Counter(counts_mageck["gene_name"]))
df = pd.DataFrame.from_dict(d, orient='index')
df.columns = ["num_sgrna"]

# %%
counts_mageck[counts_mageck["gene_name"] == "PELO"]
# Out:
#                       gene_name  K562_BRQ_CD235a_High  K562_BRQ_CD235a_Low  \
# sgID
# PELO_-_52083812.23-P2      PELO                   447                  426
# PELO_-_52084090.23-P2      PELO                   542                  807
# PELO_+_52084210.23-P2      PELO                   635                  574
# PELO_+_52084207.23-P2      PELO                   705                  605
# PELO_+_52083762.23-P2      PELO                   602                  382
# PELO_+_52084161.23-P2      PELO                   790                  801
# PELO_-_52084105.23-P2      PELO                   296                  366
# PELO_-_52084070.23-P2      PELO                   799                  886
#
#                        K562_DMSO_CD235a_All  K562_DMSO_CD235a_High  \
# sgID
# PELO_-_52083812.23-P2                   339                    490
# PELO_-_52084090.23-P2                   875                    827
# PELO_+_52084210.23-P2                   715                    721
# PELO_+_52084207.23-P2                   771                    787
# PELO_+_52083762.23-P2                   425                    520
# PELO_+_52084161.23-P2                   752                    777
# PELO_-_52084105.23-P2                   379                    362
# PELO_-_52084070.23-P2                   819                    879
#
#                        K562_DMSO_CD235a_Low  K562_DMSO_CD61_All  \
# sgID
# PELO_-_52083812.23-P2                   381                 372
# PELO_-_52084090.23-P2                   601                 529
# PELO_+_52084210.23-P2                   771                 714
# PELO_+_52084207.23-P2                  1000                 630
# PELO_+_52083762.23-P2                   516                 400
# PELO_+_52084161.23-P2                   957                1068
# PELO_-_52084105.23-P2                   305                 347
# PELO_-_52084070.23-P2                   792                 686
#
#                        K562_DMSO_CD61_High  K562_DMSO_CD61_Low  \
# sgID
# PELO_-_52083812.23-P2                  264                 265
# PELO_-_52084090.23-P2                  680                 318
# PELO_+_52084210.23-P2                  666                 485
# PELO_+_52084207.23-P2                  631                 469
# PELO_+_52083762.23-P2                  230                 220
# PELO_+_52084161.23-P2                  532                 553
# PELO_-_52084105.23-P2                  222                 207
# PELO_-_52084070.23-P2                  483                 480
#
#                        K562_HU_CD235a_All  ...  THP-1_DMSO_CD14_Low  \
# sgID                                       ...
# PELO_-_52083812.23-P2                 444  ...                  292
# PELO_-_52084090.23-P2                 508  ...                  432
# PELO_+_52084210.23-P2                 758  ...                  374
# PELO_+_52084207.23-P2                 814  ...                  391
# PELO_+_52083762.23-P2                 327  ...                  235
# PELO_+_52084161.23-P2                 664  ...                  606
# PELO_-_52084105.23-P2                 210  ...                  164
# PELO_-_52084070.23-P2                 529  ...                  596
#
#                        THP-1_HU_CD11b_All  THP-1_HU_CD11b_High  \
# sgID
# PELO_-_52083812.23-P2                 201                  159
# PELO_-_52084090.23-P2                 401                  389
# PELO_+_52084210.23-P2                 407                  344
# PELO_+_52084207.23-P2                 449                  335
# PELO_+_52083762.23-P2                 266                  208
# PELO_+_52084161.23-P2                 453                  342
# PELO_-_52084105.23-P2                 117                  205
# PELO_-_52084070.23-P2                 439                  390
#
#                        THP-1_HU_CD11b_Low  THP-1_HU_CD14_All  \
# sgID
# PELO_-_52083812.23-P2                 210                245
# PELO_-_52084090.23-P2                 483                514
# PELO_+_52084210.23-P2                 395                453
# PELO_+_52084207.23-P2                 453                431
# PELO_+_52083762.23-P2                 267                316
# PELO_+_52084161.23-P2                 412                509
# PELO_-_52084105.23-P2                 156                190
# PELO_-_52084070.23-P2                 521                476
#
#                        THP-1_HU_CD14_High  THP-1_HU_CD14_Low  \
# sgID
# PELO_-_52083812.23-P2                 146                212
# PELO_-_52084090.23-P2                 360                402
# PELO_+_52084210.23-P2                 328                488
# PELO_+_52084207.23-P2                 411                371
# PELO_+_52083762.23-P2                 305                177
# PELO_+_52084161.23-P2                 482                640
# PELO_-_52084105.23-P2                 178                176
# PELO_-_52084070.23-P2                 451                447
#
#                        THP-1_PMA_CD14_High  THP-1_PMA_CD14_Low  THP-1___Pre
# sgID
# PELO_-_52083812.23-P2                  395                 426          303
# PELO_-_52084090.23-P2                  788                 794          825
# PELO_+_52084210.23-P2                  678                 579          676
# PELO_+_52084207.23-P2                  538                 695          765
# PELO_+_52083762.23-P2                  409                 347          446
# PELO_+_52084161.23-P2                  789                 847          758
# PELO_-_52084105.23-P2                  247                 307          348
# PELO_-_52084070.23-P2                  646                 822          811
#
# [8 rows x 35 columns]

# %%
# get rid of all genes with fewer than 8 sgRNAs
df[df["num_sgrna"] < 8]
# Out:
#          num_sgrna
# ACTN3            1
# ADRB1            1
# AIDA             3
# AK5              1
# AMDHD1           2
# ...            ...
# XRN2             1
# ZNF385D          1
# ZNF605           1
# ZNF700           1
# ZNF763           1
#
# [67 rows x 1 columns]

# %%
valid_genes = df[df["num_sgrna"] >= 8].index
counts_mageck = counts_mageck[counts_mageck["gene_name"].isin(list(valid_genes))]

# %%
counts_mageck.to_csv("./230727_bd246_counts_mageck.txt", sep='\t')

# %%
# negative control genes -- should just be a list
neg_ctrl = counts_mageck[counts_mageck["gene_name"] == "non-targeting"].index
list(neg_ctrl)
# Out:
# ['non-targeting_00001',
#  'non-targeting_00002',
#  'non-targeting_00012',
#  'non-targeting_00018',
#  'non-targeting_00022',
#  'non-targeting_00039',
#  'non-targeting_00040',
#  'non-targeting_00044',
#  'non-targeting_00051',
#  'non-targeting_00063',
#  'non-targeting_00065',
#  'non-targeting_00069',
#  'non-targeting_00074',
#  'non-targeting_00076',
#  'non-targeting_00091',
#  'non-targeting_00106',
#  'non-targeting_00111',
#  'non-targeting_00116',
#  'non-targeting_00142',
#  'non-targeting_00148',
#  'non-targeting_00160',
#  'non-targeting_00162',
#  'non-targeting_00180',
#  'non-targeting_00199',
#  'non-targeting_00221',
#  'non-targeting_00223',
#  'non-targeting_00230',
#  'non-targeting_00232',
#  'non-targeting_00233',
#  'non-targeting_00261',
#  'non-targeting_00275',
#  'non-targeting_00297',
#  'non-targeting_00301',
#  'non-targeting_00308',
#  'non-targeting_00309',
#  'non-targeting_00324',
#  'non-targeting_00326',
#  'non-targeting_00336',
#  'non-targeting_00342',
#  'non-targeting_00345',
#  'non-targeting_00362',
#  'non-targeting_00368',
#  'non-targeting_00378',
#  'non-targeting_00379',
#  'non-targeting_00380',
#  'non-targeting_00381',
#  'non-targeting_00404',
#  'non-targeting_00416',
#  'non-targeting_00424',
#  'non-targeting_00426',
#  'non-targeting_00430',
#  'non-targeting_00436',
#  'non-targeting_00439',
#  'non-targeting_00440',
#  'non-targeting_00449',
#  'non-targeting_00463',
#  'non-targeting_00487',
#  'non-targeting_00489',
#  'non-targeting_00496',
#  'non-targeting_00498',
#  'non-targeting_00502',
#  'non-targeting_00506',
#  'non-targeting_00512',
#  'non-targeting_00517',
#  'non-targeting_00519',
#  'non-targeting_00536',
#  'non-targeting_00548',
#  'non-targeting_00549',
#  'non-targeting_00552',
#  'non-targeting_00556',
#  'non-targeting_00557',
#  'non-targeting_00559',
#  'non-targeting_00577',
#  'non-targeting_00579',
#  'non-targeting_00590',
#  'non-targeting_00591',
#  'non-targeting_00593',
#  'non-targeting_00596',
#  'non-targeting_00612',
#  'non-targeting_00616',
#  'non-targeting_00621',
#  'non-targeting_00623',
#  'non-targeting_00624',
#  'non-targeting_00625',
#  'non-targeting_00629',
#  'non-targeting_00631',
#  'non-targeting_00632',
#  'non-targeting_00636',
#  'non-targeting_00643',
#  'non-targeting_00647',
#  'non-targeting_00651',
#  'non-targeting_00654',
#  'non-targeting_00659',
#  'non-targeting_00663',
#  'non-targeting_00664',
#  'non-targeting_00674',
#  'non-targeting_00685',
#  'non-targeting_00697',
#  'non-targeting_00699',
#  'non-targeting_00700',
#  'non-targeting_00706',
#  'non-targeting_00711',
#  'non-targeting_00721',
#  'non-targeting_00724',
#  'non-targeting_00730',
#  'non-targeting_00735',
#  'non-targeting_00736',
#  'non-targeting_00747',
#  'non-targeting_00752',
#  'non-targeting_00754',
#  'non-targeting_00765',
#  'non-targeting_00766',
#  'non-targeting_00775',
#  'non-targeting_00781',
#  'non-targeting_00783',
#  'non-targeting_00788',
#  'non-targeting_00791',
#  'non-targeting_00794',
#  'non-targeting_00796',
#  'non-targeting_00803',
#  'non-targeting_00806',
#  'non-targeting_00814',
#  'non-targeting_00822',
#  'non-targeting_00841',
#  'non-targeting_00846',
#  'non-targeting_00850',
#  'non-targeting_00883',
#  'non-targeting_00886',
#  'non-targeting_00888',
#  'non-targeting_00894',
#  'non-targeting_00904',
#  'non-targeting_00909',
#  'non-targeting_00919',
#  'non-targeting_00929',
#  'non-targeting_00933',
#  'non-targeting_00941',
#  'non-targeting_00943',
#  'non-targeting_00956',
#  'non-targeting_00974',
#  'non-targeting_00988',
#  'non-targeting_00998',
#  'non-targeting_01013',
#  'non-targeting_01026',
#  'non-targeting_01030',
#  'non-targeting_01032',
#  'non-targeting_01043',
#  'non-targeting_01045',
#  'non-targeting_01051',
#  'non-targeting_01056',
#  'non-targeting_01058',
#  'non-targeting_01059',
#  'non-targeting_01086',
#  'non-targeting_01088',
#  'non-targeting_01099',
#  'non-targeting_01104',
#  'non-targeting_01116',
#  'non-targeting_01124',
#  'non-targeting_01125',
#  'non-targeting_01128',
#  'non-targeting_01140',
#  'non-targeting_01143',
#  'non-targeting_01153',
#  'non-targeting_01159',
#  'non-targeting_01163',
#  'non-targeting_01171',
#  'non-targeting_01187',
#  'non-targeting_01191',
#  'non-targeting_01192',
#  'non-targeting_01198',
#  'non-targeting_01210',
#  'non-targeting_01219',
#  'non-targeting_01229',
#  'non-targeting_01230',
#  'non-targeting_01231',
#  'non-targeting_01239',
#  'non-targeting_01243',
#  'non-targeting_01268',
#  'non-targeting_01278',
#  'non-targeting_01280',
#  'non-targeting_01290',
#  'non-targeting_01293',
#  'non-targeting_01298',
#  'non-targeting_01301',
#  'non-targeting_01303',
#  'non-targeting_01308',
#  'non-targeting_01314',
#  'non-targeting_01324',
#  'non-targeting_01327',
#  'non-targeting_01341',
#  'non-targeting_01352',
#  'non-targeting_01354',
#  'non-targeting_01367',
#  'non-targeting_01373',
#  'non-targeting_01380',
#  'non-targeting_01381',
#  'non-targeting_01415',
#  'non-targeting_01417',
#  'non-targeting_01418',
#  'non-targeting_01420',
#  'non-targeting_01423',
#  'non-targeting_01425',
#  'non-targeting_01427',
#  'non-targeting_01430',
#  'non-targeting_01455',
#  'non-targeting_01456',
#  'non-targeting_01466',
#  'non-targeting_01474',
#  'non-targeting_01497',
#  'non-targeting_01505',
#  'non-targeting_01514',
#  'non-targeting_01516',
#  'non-targeting_01518',
#  'non-targeting_01522',
#  'non-targeting_01525',
#  'non-targeting_01530',
#  'non-targeting_01540',
#  'non-targeting_01541',
#  'non-targeting_01553',
#  'non-targeting_01561',
#  'non-targeting_01566',
#  'non-targeting_01569',
#  'non-targeting_01572',
#  'non-targeting_01577',
#  'non-targeting_01583',
#  'non-targeting_01610',
#  'non-targeting_01619',
#  'non-targeting_01629',
#  'non-targeting_01638',
#  'non-targeting_01640',
#  'non-targeting_01645',
#  'non-targeting_01657',
#  'non-targeting_01666',
#  'non-targeting_01672',
#  'non-targeting_01689',
#  'non-targeting_01690',
#  'non-targeting_01696',
#  'non-targeting_01700',
#  'non-targeting_01710',
#  'non-targeting_01714',
#  'non-targeting_01721',
#  'non-targeting_01725',
#  'non-targeting_01727',
#  'non-targeting_01759',
#  'non-targeting_01765',
#  'non-targeting_01784',
#  'non-targeting_01793',
#  'non-targeting_01794',
#  'non-targeting_01803',
#  'non-targeting_01809',
#  'non-targeting_01811',
#  'non-targeting_01845',
#  'non-targeting_01857',
#  'non-targeting_01859',
#  'non-targeting_01885',
#  'non-targeting_01898',
#  'non-targeting_01907',
#  'non-targeting_01921',
#  'non-targeting_01928',
#  'non-targeting_01938',
#  'non-targeting_01941',
#  'non-targeting_01947',
#  'non-targeting_01958',
#  'non-targeting_01965',
#  'non-targeting_01972',
#  'non-targeting_01980',
#  'non-targeting_01985',
#  'non-targeting_01993',
#  'non-targeting_01995',
#  'non-targeting_01999',
#  'non-targeting_02018',
#  'non-targeting_02019',
#  'non-targeting_02031',
#  'non-targeting_02035',
#  'non-targeting_02040',
#  'non-targeting_02041',
#  'non-targeting_02047',
#  'non-targeting_02054',
#  'non-targeting_02057',
#  'non-targeting_02065',
#  'non-targeting_02079',
#  'non-targeting_02092',
#  'non-targeting_02106',
#  'non-targeting_02119',
#  'non-targeting_02122',
#  'non-targeting_02124',
#  'non-targeting_02133',
#  'non-targeting_02143',
#  'non-targeting_02161',
#  'non-targeting_02162',
#  'non-targeting_02172',
#  'non-targeting_02173',
#  'non-targeting_02187',
#  'non-targeting_02200',
#  'non-targeting_02216',
#  'non-targeting_02217',
#  'non-targeting_02233',
#  'non-targeting_02239',
#  'non-targeting_02241',
#  'non-targeting_02245',
#  'non-targeting_02246',
#  'non-targeting_02266',
#  'non-targeting_02275',
#  'non-targeting_02280',
#  'non-targeting_02281',
#  'non-targeting_02282',
#  'non-targeting_02306',
#  'non-targeting_02310',
#  'non-targeting_02312',
#  'non-targeting_02323',
#  'non-targeting_02340',
#  'non-targeting_02346',
#  'non-targeting_02376',
#  'non-targeting_02381',
#  'non-targeting_02387',
#  'non-targeting_02388',
#  'non-targeting_02400',
#  'non-targeting_02402',
#  'non-targeting_02403',
#  'non-targeting_02413',
#  'non-targeting_02414',
#  'non-targeting_02420',
#  'non-targeting_02451',
#  'non-targeting_02458',
#  'non-targeting_02473',
#  'non-targeting_02479',
#  'non-targeting_02487',
#  'non-targeting_02489',
#  'non-targeting_02522',
#  'non-targeting_02525',
#  'non-targeting_02530',
#  'non-targeting_02532',
#  'non-targeting_02533',
#  'non-targeting_02534',
#  'non-targeting_02538',
#  'non-targeting_02559',
#  'non-targeting_02561',
#  'non-targeting_02562',
#  'non-targeting_02564',
#  'non-targeting_02574',
#  'non-targeting_02587',
#  'non-targeting_02592',
#  'non-targeting_02604',
#  'non-targeting_02609',
#  'non-targeting_02613',
#  'non-targeting_02618',
#  'non-targeting_02619',
#  'non-targeting_02640',
#  'non-targeting_02653',
#  'non-targeting_02656',
#  'non-targeting_02662',
#  'non-targeting_02670',
#  'non-targeting_02678',
#  'non-targeting_02680',
#  'non-targeting_02709',
#  'non-targeting_02715',
#  'non-targeting_02721',
#  'non-targeting_02723',
#  'non-targeting_02727',
#  'non-targeting_02760',
#  'non-targeting_02768',
#  'non-targeting_02772',
#  'non-targeting_02776',
#  'non-targeting_02783',
#  'non-targeting_02786',
#  'non-targeting_02789',
#  'non-targeting_02795',
#  'non-targeting_02805',
#  'non-targeting_02807',
#  'non-targeting_02816',
#  'non-targeting_02824',
#  'non-targeting_02834',
#  'non-targeting_02835',
#  'non-targeting_02845',
#  'non-targeting_02857',
#  'non-targeting_02860',
#  'non-targeting_02869',
#  'non-targeting_02872',
#  'non-targeting_02883',
#  'non-targeting_02894',
#  'non-targeting_02898',
#  'non-targeting_02906',
#  'non-targeting_02918',
#  'non-targeting_02931',
#  'non-targeting_02937',
#  'non-targeting_02938',
#  'non-targeting_02950',
#  'non-targeting_02953',
#  'non-targeting_02959',
#  'non-targeting_02961',
#  'non-targeting_03004',
#  'non-targeting_03008',
#  'non-targeting_03013',
#  'non-targeting_03014',
#  'non-targeting_03019',
#  'non-targeting_03030',
#  'non-targeting_03034',
#  'non-targeting_03035',
#  'non-targeting_03037',
#  'non-targeting_03057',
#  'non-targeting_03059',
#  'non-targeting_03060',
#  'non-targeting_03062',
#  'non-targeting_03065',
#  'non-targeting_03070',
#  'non-targeting_03071',
#  'non-targeting_03079',
#  'non-targeting_03081',
#  'non-targeting_03082',
#  'non-targeting_03086',
#  'non-targeting_03092',
#  'non-targeting_03098',
#  'non-targeting_03101',
#  'non-targeting_03103',
#  'non-targeting_03112',
#  'non-targeting_03122',
#  'non-targeting_03132',
#  'non-targeting_03146',
#  'non-targeting_03149',
#  'non-targeting_03185',
#  'non-targeting_03190',
#  'non-targeting_03195',
#  'non-targeting_03207',
#  'non-targeting_03211',
#  'non-targeting_03215',
#  'non-targeting_03225',
#  'non-targeting_03230',
#  'non-targeting_03241',
#  'non-targeting_03246',
#  'non-targeting_03249',
#  'non-targeting_03264',
#  'non-targeting_03271',
#  'non-targeting_03283',
#  'non-targeting_03295',
#  'non-targeting_03296',
#  'non-targeting_03300',
#  'non-targeting_03309',
#  'non-targeting_03311',
#  'non-targeting_03319',
#  'non-targeting_03320',
#  'non-targeting_03322',
#  'non-targeting_03331',
#  'non-targeting_03339',
#  'non-targeting_03345',
#  'non-targeting_03347',
#  'non-targeting_03350',
#  'non-targeting_03354',
#  'non-targeting_03355',
#  'non-targeting_03368',
#  'non-targeting_03373',
#  'non-targeting_03375',
#  'non-targeting_03388',
#  'non-targeting_03394',
#  'non-targeting_03406',
#  'non-targeting_03409',
#  'non-targeting_03410',
#  'non-targeting_03412',
#  'non-targeting_03418',
#  'non-targeting_03432',
#  'non-targeting_03441',
#  'non-targeting_03446',
#  'non-targeting_03450',
#  'non-targeting_03470',
#  'non-targeting_03475',
#  'non-targeting_03482',
#  'non-targeting_03503',
#  'non-targeting_03515',
#  'non-targeting_03519',
#  'non-targeting_03523',
#  'non-targeting_03567',
#  'non-targeting_03571',
#  'non-targeting_03575',
#  'non-targeting_03576',
#  'non-targeting_03584',
#  'non-targeting_03585',
#  'non-targeting_03600',
#  'non-targeting_03626',
#  'non-targeting_03637',
#  'non-targeting_03641',
#  'non-targeting_03658',
#  'non-targeting_03664',
#  'non-targeting_03676',
#  'non-targeting_03680',
#  'non-targeting_03682',
#  'non-targeting_03692',
#  'non-targeting_03702',
#  'non-targeting_03722',
#  'non-targeting_03727',
#  'non-targeting_03742',
#  'non-targeting_03745',
#  'non-targeting_03755',
#  'non-targeting_03772',
#  'non-targeting_03788']

# %%
with open("230727_bd246_negative_controls.txt", 'w') as f:
    for n in neg_ctrl:
        f.write(n)
        f.write("\n")
